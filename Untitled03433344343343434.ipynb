# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import r2_score

# %%
stock_name = input("Enter stock name (e.g., AAPL, GOOGL): ")
start_date = input("Enter start date (YYYY-MM-DD): ")
end_date = input("Enter end date (YYYY-MM-DD): ")

data = yf.download(stock_name, start=start_date, end=end_date, interval='1d')

print(data.head())
# Out:
# Enter stock name (e.g., AAPL, GOOGL): AAPL
# Enter start date (YYYY-MM-DD): 2016-01-01
# Enter end date (YYYY-MM-DD): 2020-12-31
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-01-04  23.860582  23.865113  23.101846  23.240004  270597600
# 2016-01-05  23.262651  23.973826  23.194706  23.951177  223164000
# 2016-01-06  22.807415  23.185653  22.619431  22.775707  273829600
# 2016-01-07  21.844835  22.678314  21.840306  22.349906  324377600
# 2016-01-08  21.960342  22.447293  21.915045  22.320460  283192000

# %%
plt.figure(figsize=(10, 6))

plt.plot(data['Adj Close'] if 'Adj Close' in data.columns else data['Close'], label='Adjusted Close Price')
plt.title(f'{stock_name} Adjusted Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['Adj Close'] if 'Adj Close' in data.columns else data['Close'], label='Adjusted Close Price')
plt.title(f'{stock_name} Adjusted Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
data['MA_50'] = data['Close'].rolling(window=50).mean()
data['MA_200'] = data['Close'].rolling(window=200).mean()

plt.figure(figsize=(10, 6))
plt.plot(data['Close'], label='Adjusted Close')
plt.plot(data['MA_50'], label='50-Day Moving Average')
plt.plot(data['MA_200'], label='200-Day Moving Average')
plt.title('Moving Averages')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
def compute_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

price_column = 'Adj Close' if 'Adj Close' in data.columns else 'Close'
data['RSI'] = compute_rsi(data[price_column])

plt.figure(figsize=(10, 6))
plt.plot(data['RSI'], label='RSI', color='orange')
plt.title('Relative Strength Index (RSI)')
plt.xlabel('Date')
plt.ylabel('RSI')
plt.axhline(30, color='red', linestyle='--', linewidth=0.5)
plt.axhline(70, color='green', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2016-01-04   23.860582   23.865113   23.101846   23.240004  270597600
# 2016-01-05   23.262651   23.973826   23.194706   23.951177  223164000
# 2016-01-06   22.807415   23.185653   22.619431   22.775707  273829600
# 2016-01-07   21.844835   22.678314   21.840306   22.349906  324377600
# 2016-01-08   21.960342   22.447293   21.915045   22.320460  283192000
# ...                ...         ...         ...         ...        ...
# 2020-12-23  128.059906  129.497339  127.883884  129.233329   88223700
# 2020-12-24  129.047546  130.504556  128.196817  128.411947   54930100
# 2020-12-28  133.663025  134.298625  130.553438  131.022819  124486200
# 2020-12-29  131.883301  135.716491  131.365039  134.992887  121047300
# 2020-12-30  130.758789  132.978524  130.445868  132.577600   96452100
#
# Price            MA_50     MA_200        RSI
# ...

# %%
data = data[[price_column, 'MA_50', 'RSI']].dropna()

price_column = 'Adj Close' if 'Adj Close' in data.columns else 'Close'
data = data[[price_column, 'MA_50', 'RSI']].dropna()

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

training_size = int(len(scaled_data) * 0.8)
train_data = scaled_data[:training_size]
test_data = scaled_data[training_size:]

def create_sequences(dataset, time_step=60):
    X, y = [], []
    for i in range(len(dataset) - time_step - 1):
        X.append(dataset[i:(i + time_step), :])
        y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(y)

time_step = 60
X_train, y_train = create_sequences(train_data, time_step)
X_test, y_test = create_sequences(test_data, time_step)

# %%
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
model.fit(X_train, y_train, batch_size=32, epochs=20)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0092
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 4.0571e-04
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 2.2815e-04
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 2.0353e-04
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.7918e-04
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.6908e-04
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.6298e-04
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - loss: 1.3587e-04
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.3464e-04
# Epoch 10/20
# ...

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(np.concatenate([predictions, np.zeros((len(predictions), 2))], axis=1))[:, 0]

y_test_actual = scaler.inverse_transform(np.concatenate([y_test.reshape(-1, 1), np.zeros((len(y_test), 2))], axis=1))[:, 0]
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step

# %%
r2 = r2_score(y_test_actual, predictions)
print(f"R² Score: {r2}")
plt.figure(figsize=(10, 6))
plt.plot(y_test_actual, label='Actual Prices')
plt.plot(predictions, label='Predicted Prices')
plt.title(f'{stock_name} Actual vs Predicted Prices')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# R² Score: 0.7373627714651182

# %%
last_sequence = test_data[-time_step:]
next_predictions = []

for _ in range(15):
    pred = model.predict(last_sequence.reshape(1, time_step, 3))
    next_predictions.append(pred[0, 0])
    pred_reshaped = pred.reshape(1, 1, 1)

    pred_reshaped = np.repeat(pred_reshaped, 3, axis=2)
    pred_reshaped = pred_reshaped.reshape(1,3)

    last_sequence = np.concatenate([last_sequence[1:], pred_reshaped], axis=0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
